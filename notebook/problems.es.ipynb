# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
#Distribución Normal
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

def dnorm(x, mean=0, sd=1):
#Función de la densidad de probabilidad (PDF) distribución normal
    result = norm.pdf(x, loc=mean, scale=sd)
    return result

def pnorm(q, mean=0, sd=1):
 #Distribución acumulativa (CDF) DISTRIBUCIÓN NORMAL   
    result = norm.cdf(q, loc=mean, scale=sd)
    return result

def qnorm(p, mean=0, sd=1):
#Función cuantil (PPF) DISTRIBUCIÓN NORMAL
    result = norm.ppf(p, loc=mean, scale=sd)
    return result

def rnorm(n, mean=0, sd=1):
#Genera variablesa aleatorias distribución normal
    result = norm.rvs(loc=mean, scale=sd, size=n)
    return result

# Ejemplo de uso con distribución normal N(0, 1)
np.random.seed(42)


print(f"Probability density of Normal(0, 1) at value 0: {dnorm(0)}")
print(f"Cumulative probability of Normal(0, 1) less than 0: {pnorm(0)}")
print(f"Which value of Normal(0, 1) has a cumulative probability of 0.95? {qnorm(0.95)}")
print(f"Generate 10 random values from a Normal(0, 1) distribution: {rnorm(10)}")
# Out:
# Probability density of Normal(0, 1) at value 0: 0.3989422804014327
# Cumulative probability of Normal(0, 1) less than 0: 0.5
# Which value of Normal(0, 1) has a cumulative probability of 0.95? 1.6448536269514722
# Generate 10 random values from a Normal(0, 1) distribution: [ 0.49671415 -0.1382643   0.64768854  1.52302986 -0.23415337 -0.23413696
#   1.57921282  0.76743473 -0.46947439  0.54256004]

# %%
#Gráfica distribución Uniforme
# Generar y graficar valores aleatorios de una distribución normal N(0, 1)
data_norm = rnorm(2000, mean=0, sd=1)
pdf_norm = dnorm(data_norm, mean=0, sd=1)
cdf_norm = pnorm(data_norm, mean=0, sd=1)

fig, axis = plt.subplots(2, 1, figsize=(5, 7))

axis[0].hist(data_norm, bins=30, density=True, alpha=0.6, color='y')
axis[0].plot(sorted(data_norm), sorted(pdf_norm), 'r-')
axis[0].set_title('PDF of Normal Distribution')

axis[1].hist(data_norm, bins=30, density=True, alpha=0.6, color='m', cumulative=True)
axis[1].plot(sorted(data_norm), sorted(cdf_norm), 'b-')
axis[1].set_title('CDF of Normal Distribution')

plt.tight_layout()
plt.show()

# %%
#Distribución Uniforme
import numpy as np
from scipy.stats import uniform
import matplotlib.pyplot as plt


def dunif(x, min=0, max=1):
#Densidad de probabilidad (PDF) DISTRIBUCIÓN UNIFORME   
    result = uniform.pdf(x, loc=min, scale=max-min)
    return result

def punif(q, min=0, max=1):
#Distribución acumulativa (CDF) DISTRIBUCIÓN UNIFORME 
    result = uniform.cdf(q, loc=min, scale=max-min)
    return result

def qunif(p, min=0, max=1):
#fUNCIÓN CUANTIL (PPF) DISTRIBUCIÓN UNIFORME 
    result = uniform.ppf(p, loc=min, scale=max-min)
    return result

def runif(n, min=0, max=1):
#VARIABLES ALEATORIAS DISTRIBUCIÓN UNIFORME 
    result = uniform.rvs(loc=min, scale=max-min, size=n)
    return result

# Ejemplo de uso con distribución uniforme U(0, 1)
np.random.seed(42)

print(f"Probability density of Uniform(0, 1) at value 0.5: {dunif(0.5)}")
print(f"Cumulative probability of Uniform(0, 1) less than 0.5: {punif(0.5)}")
print(f"Which value of Uniform(0, 1) has a cumulative probability of 0.95? {qunif(0.95)}")
print(f"Generate 10 random values from a Uniform(0, 1) distribution: {runif(10)}")
# Out:
# Probability density of Uniform(0, 1) at value 0.5: 1.0
# Cumulative probability of Uniform(0, 1) less than 0.5: 0.5
# Which value of Uniform(0, 1) has a cumulative probability of 0.95? 0.95
# Generate 10 random values from a Uniform(0, 1) distribution: [0.37454012 0.95071431 0.73199394 0.59865848 0.15601864 0.15599452
#  0.05808361 0.86617615 0.60111501 0.70807258]

# %%
#GRÁFICOS DISTRIBUCIÓN UNIFORME
data_unif = runif(2000, min=0, max=1)
pdf_unif = dunif(data_unif, min=0, max=1)
cdf_unif = punif(data_unif, min=0, max=1)

fig, axis = plt.subplots(2, 1, figsize=(5, 7))

axis[0].hist(data_unif, bins=30, density=True, alpha=0.6, color='m')
axis[0].plot(sorted(data_unif), sorted(pdf_unif), 'r-')
axis[0].set_title('PDF of Uniform Distribution')

axis[1].hist(data_unif, bins=30, density=True, alpha=0.6, color='g', cumulative=True)
axis[1].plot(sorted(data_unif), sorted(cdf_unif), 'b-')
axis[1].set_title('CDF of Uniform Distribution')

plt.tight_layout()
plt.show()
